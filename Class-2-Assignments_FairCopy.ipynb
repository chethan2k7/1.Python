# %%
from Class2Assignments import AllFunctions

# %%
AllFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
AllFunctions.OddEven()
# Out:
# Enter a number: 52452
# is Even number

# %%
AllFunctions.Eligible()
# Out:
# Enter Gender (Male/Female):  Male
# Enter Age:  20
# Not Eligible for marriage

# %%
AllFunctions.percentage(98,87,95,95,93)
# Out:
# Total: 468
# Percentage: 93.6

# %%
AllFunctions.trianglePerimeter(2,4,4)
# Out:
# 10

# %%
AllFunctions.triangleArea(32,34)
# Out:
# 544.0
